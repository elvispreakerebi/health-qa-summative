# %% [markdown]
# <a href="https://colab.research.google.com/github/elvispreakerebi/health-qa-summative/blob/main/health_qa_summative_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Health QA Summative Colab Runner
#
# This notebook runs the repo pipeline on Colab GPU. Keep reusable logic in `src/health_qa`; use this notebook as the execution layer.

# %%
# !git clone https://github.com/elvispreakerebi/health-qa-summative.git
# %cd health-qa-summative
# !pip install -q -r requirements.txt
# !pip install -q -e .

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Set `DATA_DIR` to the Drive folder containing `Train.csv`, `Val.csv`, and `Test.csv`. If the shared folder is added as a shortcut to My Drive, update the path below to match its visible location.

# %%
from pathlib import Path
import yaml

DATA_DIR = Path('/content/drive/MyDrive/mlt1-summative-datasets')
config_path = Path('configs/baseline.yaml')
config = yaml.safe_load(config_path.read_text())
config['data']['raw_dir'] = str(DATA_DIR)
config_path.write_text(yaml.safe_dump(config, sort_keys=False))
print(config)

# %%
# !python -m health_qa.cli inspect-data --config configs/baseline.yaml

# %%
# !python -m health_qa.cli train-generate --config configs/baseline.yaml --output-dir outputs/baseline_mt5

# %%
import pandas as pd

metrics = pd.read_csv('outputs/baseline_mt5/metrics.csv')
submission = pd.read_csv('outputs/baseline_mt5/submission.csv')
display(metrics)
display(submission.head())
print('Submission path: outputs/baseline_mt5/submission.csv')
